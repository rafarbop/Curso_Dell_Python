# %% [markdown]
# # Oficina 3.1

# %% [markdown]
# Nesta oficina, continue explorando os dados imobiliários que você acompanhou durante a aula. Crie um Jupyter Notebook e responda cada questão com código em uma célula.

# %% [markdown]
# 1. Importe as bibliotecas pandas, matplotlib e seaborn e use a palavra mágica inline para exibir as visualizações no notebook. Carregue os dados em um DataFrame. Os dados estão disponibilizados no link: [dados](https://d11s0xq1vqg039.cloudfront.net/videos_conteudo/visual/micro05/oficina/arquivos/dadosoficina05.txt). Você pode carregar os dados pela URI ou salvar em sua máquina e carregá-los localmente

# %%
import pandas as pd
import matplotlib.pyplot as plot
import seaborn

# %% [markdown]
# 2. Crie uma visualização que mostre a distribuição dos valores de aluguel, ‘rent amount (R$)’, dos imóveis. Pode utilizar o gráfico que você julgar mais adequado. Qual faixa de valores de aluguel é mais comum?

# %%
df = pd.read_csv('dadosoficina05.txt')
df
# Out:
#                 city  area  rooms  bathroom  parking spaces floor     animal  \
# 0          São Paulo    70      2         1               1     7      acept
# 1       Porto Alegre    80      1         1               1     6      acept
# 2       Porto Alegre    51      2         1               0     2      acept
# 3          São Paulo    25      1         1               0     1  not acept
# 4     Rio de Janeiro    72      2         1               0     7      acept
# ...              ...   ...    ...       ...             ...   ...        ...
# 8199       São Paulo   150      3         3               2     8  not acept
# 8200    Porto Alegre    63      2         1               1     5  not acept
# 8201  Rio de Janeiro    70      3         3               0     8  not acept
# 8202  Rio de Janeiro   120      2         2               2     8      acept
# 8203       São Paulo    80      2         1               0     -      acept
#
# ...

# %% [markdown]
# 3. Crie uma visualização que mostre a distribuição dos valores de seguro contra incêndio, 'fire insurance (R$)', dos imóveis. Existem valores incomuns?

# %%
plot.figure(figsize=(10,6))
plot.title('Distribuição dos valores de seguro contra incêndio')
plot.grid(axis='y',ls='dashed')
seaborn.histplot(df['fire insurance (R$)'],binwidth=10)
plot.show()

# %%
df['fire insurance (R$)'].describe()
# Out:
# count    8204.000000
# mean       36.510605
# std        28.121018
# min         3.000000
# 25%        18.000000
# 50%        28.000000
# 75%        45.000000
# max       305.000000
# Name: fire insurance (R$), dtype: float64

# %% [markdown]
# **Resposta:**
#
# A maioria (75%) dos valores dos seguros são de até 45 Reais, porém existem alguns seguros que chegam cerca de 300 reais.
#
# A faixa de valores que contém mais seguros é a de 10 a 20 reais, cerca de 2400 seguros são entre esses valores.
